# %%
print('\t\t\t...........AIRPORT BOOKING TICKET.........')
def air(w) :
        print('\n\t\t\t..........Pay the money..........')
        print('Your amount is :',w)
        s=int(input('Rs(pay your amount) : '))
        if(s==5000) | (s==2000) | (s==10000):
	            
                print('\t\t\t........your payment is sucessfully completed.......')
                print('\t\t\t\n\n\tYOUR BOOKING IS COMFORMED...')
                print('\n\tHAVE A NICE JOURNEY')
        else:
            print('\n\t\t\tplease...pay correct amount....')
            air(w)

def country():
           
            w=input('Enter the country (type correctly):')
           
            if w=='Dubai':
                    w =5000
                    print('\n\t\t\t',a,'your selection is conformed......')
                    air(w)
            elif w=='chennai':
                    w = 2000
                    print('\n\t\t\t',a,'your selection is conformed......')
                    air(w)
            elif w=='singapore':
                    w =  10000
                    print('\n\t\t\t',a,'your selection is conformed......')
                    air(w)
            else:
                print('\t\t\tSorry ...This place not available')
                book()
def detail():
            A=input('\nyou conform booking ticket (yes/no) :')
            if(A =='yes') | (A=='y'):
                        a=input('Enter the Name : ')
                        b=input('Enter the Age  :')
                        print('\t\t\t.....welcome to PYTHON AIR LINE ....\n')
                        print('\t\t\t.........Select the country......\n')
                        print('\t\t\tDubai     = 5000')
                        print('\t\t\tchennai   = 2000')
                        print('\t\t\tsingapore = 10000')
                        print('\n ..Only avaliable Three places')
                        country()
            else:
                        print('\t\t\t........THANK YOU........\n')
                        print('\n\t\t\tyour booking is failed')
                        c=input('are you try one more time (yes\no) : ')
                        if (c=='yes') | (c=='y'):
                               detail()
                        else:
                               print('ok')
        
def book():
    print('\n\t\t\tyour booking is failed')
detail()
# Out:
# 			...........AIRPORT BOOKING TICKET.........
#
# you conform booking ticket (yes/no) :y
# Enter the Name : arish
# Enter the Age  :23
# 			.....welcome to PYTHON AIR LINE ....
#
# 			.........Select the country......
#
# 			Dubai     = 5000
# 			chennai   = 2000
# 			singapore = 10000
#
#  ..Only avaliable Three places
# Enter the country (type correctly):Dubai
#
# 			 ad your selection is conformed......
#
# 			..........Pay the money..........
# Your amount is : 5000
# Rs(pay your amount) : 5000
# 			........your payment is sucessfully completed.......
#
#
# 	YOUR BOOKING IS COMFORMED...
#
# 	HAVE A NICE JOURNEY
